from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
from xgboost import XGBClassifier
from scipy import signal

# Define the class labels
class_labels = {
    'yukarı':0 ,
    'yukari': 0,
    'asagi': 1,
    'sag': 2,
    'sol': 3,
    'kirp': 4
}

class_names = {
    0: 'Up',
    1: 'Down',
    2: 'Right',
    3: 'Left',
    4: 'Blink'
}

h=[]
classes=class_labels.keys()

# Define the butter_lowpass_filter function
def butter_bandpass_filter(Input_Signal,LOW_Cutoff,High_cuttOff,Sampling_Rate,order):
    nyq = 0.5 *Sampling_Rate
    low = LOW_Cutoff/ nyq
    high = High_cuttOff / nyq
    Numerator,denominator = butter(order,[low,high],btype = "band",output = "ba",analog = False,fs = None)
    filtered = filtfilt(Numerator,denominator,Input_Signal)
    return filtered

def rsample_filter(Filtered_Data):
    resampled_Signal = []
    for i in Filtered_Data:
        re_Sgnl = signal.resample(i,60)
        resampled_Signal.append(re_Sgnl)
    return resampled_Signal

def extract_raw_features(signal):
    # Compute statistical features
    mean_value = np.mean(signal)
    variance = np.var(signal)
    skewness = scipy.stats.skew(signal)
    kurtosis = scipy.stats.kurtosis(signal)
    # Compute frequency-domain features using FFT
    fft_result = np.fft.fft(signal)
    spectral_power = np.abs(fft_result) ** 2
    return [mean_value, variance, skewness, kurtosis] + list(spectral_power)

def extract_wavelet_features(signal, wavelet='db4', level=3):
    # Perform wavelet decomposition
    coeffs = pywt.wavedec(signal, wavelet, level=level)
    wavelet_features = []
    # Extract statistical features from wavelet coefficients
    for coeff in coeffs:
        mean_value = np.mean(coeff)
        variance = np.var(coeff)
        energy = np.sum(np.square(coeff))
        entropy = -np.sum(np.square(coeff) * np.log(np.square(coeff)))
        wavelet_features.extend([mean_value, variance, energy, entropy])
    return wavelet_features

# Open the CSV file for writing
with open('Edata.csv', 'w') as csv_file:
    for filename in glob.glob('C:/Users/AlQla/3-class/*.txt'):
        # Get the class label from the filename
        print(filename)
        h = filename.split('\\')[-1].split('.')[0]
        matches = re.split(r'(\d+)', h)
        print (matches)

        if len(matches)==3:
            print(len(matches))
            if matches[0] in classes :
                if  matches[2]=='h':
                    print(matches[2])
                    f=filename.replace('h','v')
                    try :
                        print(f)
                        with open(f, 'r') as file:
                            # Read the contents of the file and split it into lines
                            lines_v = file.read()
                        lines_v=lines_v.replace('\n',',')
                        for line in lines_v:
                            csv_file.write(line)
                        with open(filename, 'r') as file:
                            # Read the contents of the file and split it into lines
                            lines_h = file.read()
                        lines_h=lines_h.replace('\n',',')
                        for line in lines_h:
                            csv_file.write(line)

                        label = class_labels[matches[0]]
                        csv_file.write(str(label)+'\n')
                    except FileNotFoundError:
                        pass 

# Read the CSV file into a DataFrame
names=np.arange(0,503)
df = pd.read_csv('Edata.csv', names=names)
x=df.iloc[:,:-1]
y=df.iloc[:,-1:]

# Apply the butter_lowpass_filter to your data
cutoff = 10  # Choose your cutoff frequency
SamplingRate = 1000  # Provide your sampling rate
order = 5  # Choose the filter order
filtered_Signal = butter_bandpass_filter(x,LOW_Cutoff=0.5,High_cuttOff=20.0,Sampling_Rate=176,order = 2)

res_rsample=rsample_filter(filtered_Signal)


# Extract features
raw_features = np.apply_along_axis(extract_raw_features, 1, res_rsample)
wavelet_features= np.apply_along_axis(extract_wavelet_features, 1, res_rsample)
combined_features = np.concatenate((raw_features, wavelet_features), axis=1)
print(combined_features)


# Now you can use these features (raw_features and wavelet_features) for further processing or modeling
# Out:
# C:/Users/AlQla/3-class\asagi10h.txt
# ['asagi', '10', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi10v.txt
# C:/Users/AlQla/3-class\asagi10v.txt
# ['asagi', '10', 'v']
# 3
# C:/Users/AlQla/3-class\asagi11h.txt
# ['asagi', '11', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi11v.txt
# C:/Users/AlQla/3-class\asagi11v.txt
# ['asagi', '11', 'v']
# 3
# C:/Users/AlQla/3-class\asagi12h.txt
# ['asagi', '12', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi12v.txt
# C:/Users/AlQla/3-class\asagi12v.txt
# ['asagi', '12', 'v']
# 3
# C:/Users/AlQla/3-class\asagi13h.txt
# ['asagi', '13', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi13v.txt
# C:/Users/AlQla/3-class\asagi13v.txt
# ['asagi', '13', 'v']
# 3
# C:/Users/AlQla/3-class\asagi14h.txt
# ['asagi', '14', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi14v.txt
# C:/Users/AlQla/3-class\asagi14v.txt
# ['asagi', '14', 'v']
# 3
# C:/Users/AlQla/3-class\asagi15h.txt
# ['asagi', '15', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi15v.txt
# C:/Users/AlQla/3-class\asagi15v.txt
# ['asagi', '15', 'v']
# 3
# C:/Users/AlQla/3-class\asagi16h.txt
# ['asagi', '16', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi16v.txt
# C:/Users/AlQla/3-class\asagi16v.txt
# ['asagi', '16', 'v']
# 3
# C:/Users/AlQla/3-class\asagi17h.txt
# ['asagi', '17', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi17v.txt
# C:/Users/AlQla/3-class\asagi17v.txt
# ['asagi', '17', 'v']
# 3
# C:/Users/AlQla/3-class\asagi18h.txt
# ['asagi', '18', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi18v.txt
# C:/Users/AlQla/3-class\asagi18v.txt
# ['asagi', '18', 'v']
# 3
# C:/Users/AlQla/3-class\asagi19h.txt
# ['asagi', '19', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi19v.txt
# C:/Users/AlQla/3-class\asagi19v.txt
# ['asagi', '19', 'v']
# 3
# C:/Users/AlQla/3-class\asagi1h.txt
# ['asagi', '1', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi1v.txt
# C:/Users/AlQla/3-class\asagi1v.txt
# ['asagi', '1', 'v']
# 3
# C:/Users/AlQla/3-class\asagi20h.txt
# ['asagi', '20', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi20v.txt
# C:/Users/AlQla/3-class\asagi20v.txt
# ['asagi', '20', 'v']
# 3
# C:/Users/AlQla/3-class\asagi2h.txt
# ['asagi', '2', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi2v.txt
# C:/Users/AlQla/3-class\asagi2v.txt
# ['asagi', '2', 'v']
# 3
# C:/Users/AlQla/3-class\asagi3h.txt
# ['asagi', '3', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi3v.txt
# C:/Users/AlQla/3-class\asagi3v.txt
# ['asagi', '3', 'v']
# 3
# C:/Users/AlQla/3-class\asagi4h.txt
# ['asagi', '4', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi4v.txt
# C:/Users/AlQla/3-class\asagi4v.txt
# ['asagi', '4', 'v']
# 3
# C:/Users/AlQla/3-class\asagi5h.txt
# ['asagi', '5', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi5v.txt
# C:/Users/AlQla/3-class\asagi5v.txt
# ['asagi', '5', 'v']
# 3
# C:/Users/AlQla/3-class\asagi6h.txt
# ['asagi', '6', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi6v.txt
# C:/Users/AlQla/3-class\asagi6v.txt
# ['asagi', '6', 'v']
# 3
# C:/Users/AlQla/3-class\asagi7h.txt
# ['asagi', '7', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi7v.txt
# C:/Users/AlQla/3-class\asagi7v.txt
# ['asagi', '7', 'v']
# 3
# C:/Users/AlQla/3-class\asagi8h.txt
# ['asagi', '8', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi8v.txt
# C:/Users/AlQla/3-class\asagi8v.txt
# ['asagi', '8', 'v']
# 3
# C:/Users/AlQla/3-class\asagi9h.txt
# ['asagi', '9', 'h']
# 3
# h
# C:/Users/AlQla/3-class\asagi9v.txt
# C:/Users/AlQla/3-class\asagi9v.txt
# ['asagi', '9', 'v']
# 3
# C:/Users/AlQla/3-class\Edit2.txt
# ['Edit', '2', '']
# 3
# C:/Users/AlQla/3-class\Edit2h.txt
# ['Edit', '2', 'h']
# 3
# C:/Users/AlQla/3-class\Edit2v.txt
# ['Edit', '2', 'v']
# 3
# C:/Users/AlQla/3-class\kayit.txt
# ['kayit']
# C:/Users/AlQla/3-class\kirp10h.txt
# ['kirp', '10', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp10v.txt
# C:/Users/AlQla/3-class\kirp10v.txt
# ['kirp', '10', 'v']
# 3
# C:/Users/AlQla/3-class\kirp111h.txt
# ['kirp', '111', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp111v.txt
# C:/Users/AlQla/3-class\kirp11h.txt
# ['kirp', '11', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp11v.txt
# C:/Users/AlQla/3-class\kirp11v.txt
# ['kirp', '11', 'v']
# 3
# C:/Users/AlQla/3-class\kirp12h.txt
# ['kirp', '12', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp12v.txt
# C:/Users/AlQla/3-class\kirp12v.txt
# ['kirp', '12', 'v']
# 3
# C:/Users/AlQla/3-class\kirp13h.txt
# ['kirp', '13', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp13v.txt
# C:/Users/AlQla/3-class\kirp13v.txt
# ['kirp', '13', 'v']
# 3
# C:/Users/AlQla/3-class\kirp14h.txt
# ['kirp', '14', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp14v.txt
# C:/Users/AlQla/3-class\kirp14v.txt
# ['kirp', '14', 'v']
# 3
# C:/Users/AlQla/3-class\kirp15h.txt
# ['kirp', '15', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp15v.txt
# C:/Users/AlQla/3-class\kirp15v.txt
# ['kirp', '15', 'v']
# 3
# C:/Users/AlQla/3-class\kirp16h.txt
# ['kirp', '16', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp16v.txt
# C:/Users/AlQla/3-class\kirp16v.txt
# ['kirp', '16', 'v']
# 3
# C:/Users/AlQla/3-class\kirp17h.txt
# ['kirp', '17', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp17v.txt
# C:/Users/AlQla/3-class\kirp17v.txt
# ['kirp', '17', 'v']
# 3
# C:/Users/AlQla/3-class\kirp18h.txt
# ['kirp', '18', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp18v.txt
# C:/Users/AlQla/3-class\kirp18v.txt
# ['kirp', '18', 'v']
# 3
# C:/Users/AlQla/3-class\kirp19h.txt
# ['kirp', '19', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp19v.txt
# C:/Users/AlQla/3-class\kirp19v.txt
# ['kirp', '19', 'v']
# 3
# C:/Users/AlQla/3-class\kirp1h.txt
# ['kirp', '1', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp1v.txt
# C:/Users/AlQla/3-class\kirp1v.txt
# ['kirp', '1', 'v']
# 3
# C:/Users/AlQla/3-class\kirp20h.txt
# ['kirp', '20', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp20v.txt
# C:/Users/AlQla/3-class\kirp20v.txt
# ['kirp', '20', 'v']
# 3
# C:/Users/AlQla/3-class\kirp2h.txt
# ['kirp', '2', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp2v.txt
# C:/Users/AlQla/3-class\kirp2v.txt
# ['kirp', '2', 'v']
# 3
# C:/Users/AlQla/3-class\kirp3h.txt
# ['kirp', '3', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp3v.txt
# C:/Users/AlQla/3-class\kirp3v.txt
# ['kirp', '3', 'v']
# 3
# C:/Users/AlQla/3-class\kirp4h.txt
# ['kirp', '4', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp4v.txt
# C:/Users/AlQla/3-class\kirp4v.txt
# ['kirp', '4', 'v']
# 3
# C:/Users/AlQla/3-class\kirp5h.txt
# ['kirp', '5', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp5v.txt
# C:/Users/AlQla/3-class\kirp5v.txt
# ['kirp', '5', 'v']
# 3
# C:/Users/AlQla/3-class\kirp6h.txt
# ['kirp', '6', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp6v.txt
# C:/Users/AlQla/3-class\kirp6v.txt
# ['kirp', '6', 'v']
# 3
# C:/Users/AlQla/3-class\kirp7h.txt
# ['kirp', '7', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp7v.txt
# C:/Users/AlQla/3-class\kirp7v.txt
# ['kirp', '7', 'v']
# 3
# C:/Users/AlQla/3-class\kirp8h.txt
# ['kirp', '8', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp8v.txt
# C:/Users/AlQla/3-class\kirp8v.txt
# ['kirp', '8', 'v']
# 3
# C:/Users/AlQla/3-class\kirp9h.txt
# ['kirp', '9', 'h']
# 3
# h
# C:/Users/AlQla/3-class\kirp9v.txt
# C:/Users/AlQla/3-class\kirp9v.txt
# ['kirp', '9', 'v']
# 3
# C:/Users/AlQla/3-class\sag10h.txt
# ['sag', '10', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag10v.txt
# C:/Users/AlQla/3-class\sag10v.txt
# ['sag', '10', 'v']
# 3
# C:/Users/AlQla/3-class\sag11h.txt
# ['sag', '11', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag11v.txt
# C:/Users/AlQla/3-class\sag11v.txt
# ['sag', '11', 'v']
# 3
# C:/Users/AlQla/3-class\sag12h.txt
# ['sag', '12', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag12v.txt
# C:/Users/AlQla/3-class\sag12v.txt
# ['sag', '12', 'v']
# 3
# C:/Users/AlQla/3-class\sag13h.txt
# ['sag', '13', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag13v.txt
# C:/Users/AlQla/3-class\sag13v.txt
# ['sag', '13', 'v']
# 3
# C:/Users/AlQla/3-class\sag14h.txt
# ['sag', '14', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag14v.txt
# C:/Users/AlQla/3-class\sag14v.txt
# ['sag', '14', 'v']
# 3
# C:/Users/AlQla/3-class\sag15h.txt
# ['sag', '15', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag15v.txt
# C:/Users/AlQla/3-class\sag15v.txt
# ['sag', '15', 'v']
# 3
# C:/Users/AlQla/3-class\sag16h.txt
# ['sag', '16', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag16v.txt
# C:/Users/AlQla/3-class\sag16v.txt
# ['sag', '16', 'v']
# 3
# C:/Users/AlQla/3-class\sag17h.txt
# ['sag', '17', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag17v.txt
# C:/Users/AlQla/3-class\sag17v.txt
# ['sag', '17', 'v']
# 3
# C:/Users/AlQla/3-class\sag18h.txt
# ['sag', '18', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag18v.txt
# C:/Users/AlQla/3-class\sag18v.txt
# ['sag', '18', 'v']
# 3
# C:/Users/AlQla/3-class\sag19h.txt
# ['sag', '19', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag19v.txt
# C:/Users/AlQla/3-class\sag19v.txt
# ['sag', '19', 'v']
# 3
# C:/Users/AlQla/3-class\sag1h.txt
# ['sag', '1', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag1v.txt
# C:/Users/AlQla/3-class\sag1v.txt
# ['sag', '1', 'v']
# 3
# C:/Users/AlQla/3-class\sag20h.txt
# ['sag', '20', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag20v.txt
# C:/Users/AlQla/3-class\sag20v.txt
# ['sag', '20', 'v']
# 3
# C:/Users/AlQla/3-class\sag2h.txt
# ['sag', '2', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag2v.txt
# C:/Users/AlQla/3-class\sag2v.txt
# ['sag', '2', 'v']
# 3
# C:/Users/AlQla/3-class\sag3h.txt
# ['sag', '3', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag3v.txt
# C:/Users/AlQla/3-class\sag3v.txt
# ['sag', '3', 'v']
# 3
# C:/Users/AlQla/3-class\sag4h.txt
# ['sag', '4', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag4v.txt
# C:/Users/AlQla/3-class\sag4v.txt
# ['sag', '4', 'v']
# 3
# C:/Users/AlQla/3-class\sag5h.txt
# ['sag', '5', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag5v.txt
# C:/Users/AlQla/3-class\sag5v.txt
# ['sag', '5', 'v']
# 3
# C:/Users/AlQla/3-class\sag6h.txt
# ['sag', '6', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag6v.txt
# C:/Users/AlQla/3-class\sag6v.txt
# ['sag', '6', 'v']
# 3
# C:/Users/AlQla/3-class\sag7h.txt
# ['sag', '7', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag7v.txt
# C:/Users/AlQla/3-class\sag7v.txt
# ['sag', '7', 'v']
# 3
# C:/Users/AlQla/3-class\sag8h.txt
# ['sag', '8', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag8v.txt
# C:/Users/AlQla/3-class\sag8v.txt
# ['sag', '8', 'v']
# 3
# C:/Users/AlQla/3-class\sag9h.txt
# ['sag', '9', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sag9v.txt
# C:/Users/AlQla/3-class\sag9v.txt
# ['sag', '9', 'v']
# 3
# C:/Users/AlQla/3-class\serkanh.txt
# ['serkanh']
# C:/Users/AlQla/3-class\serkanv.txt
# ['serkanv']
# C:/Users/AlQla/3-class\sol10h.txt
# ['sol', '10', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol10v.txt
# C:/Users/AlQla/3-class\sol10v.txt
# ['sol', '10', 'v']
# 3
# C:/Users/AlQla/3-class\sol11h.txt
# ['sol', '11', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol11v.txt
# C:/Users/AlQla/3-class\sol11v.txt
# ['sol', '11', 'v']
# 3
# C:/Users/AlQla/3-class\sol12h.txt
# ['sol', '12', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol12v.txt
# C:/Users/AlQla/3-class\sol12v.txt
# ['sol', '12', 'v']
# 3
# C:/Users/AlQla/3-class\sol13h.txt
# ['sol', '13', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol13v.txt
# C:/Users/AlQla/3-class\sol13v.txt
# ['sol', '13', 'v']
# 3
# C:/Users/AlQla/3-class\sol14h.txt
# ['sol', '14', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol14v.txt
# C:/Users/AlQla/3-class\sol14v.txt
# ['sol', '14', 'v']
# 3
# C:/Users/AlQla/3-class\sol15h.txt
# ['sol', '15', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol15v.txt
# C:/Users/AlQla/3-class\sol15v.txt
# ['sol', '15', 'v']
# 3
# C:/Users/AlQla/3-class\sol16h.txt
# ['sol', '16', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol16v.txt
# C:/Users/AlQla/3-class\sol16v.txt
# ['sol', '16', 'v']
# 3
# C:/Users/AlQla/3-class\sol17h.txt
# ['sol', '17', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol17v.txt
# C:/Users/AlQla/3-class\sol17v.txt
# ['sol', '17', 'v']
# 3
# C:/Users/AlQla/3-class\sol18h.txt
# ['sol', '18', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol18v.txt
# C:/Users/AlQla/3-class\sol18v.txt
# ['sol', '18', 'v']
# 3
# C:/Users/AlQla/3-class\sol19h.txt
# ['sol', '19', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol19v.txt
# C:/Users/AlQla/3-class\sol19v.txt
# ['sol', '19', 'v']
# 3
# C:/Users/AlQla/3-class\sol1h.txt
# ['sol', '1', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol1v.txt
# C:/Users/AlQla/3-class\sol1v.txt
# ['sol', '1', 'v']
# 3
# C:/Users/AlQla/3-class\sol20h.txt
# ['sol', '20', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol20v.txt
# C:/Users/AlQla/3-class\sol20v.txt
# ['sol', '20', 'v']
# 3
# C:/Users/AlQla/3-class\sol2h.txt
# ['sol', '2', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol2v.txt
# C:/Users/AlQla/3-class\sol2v.txt
# ['sol', '2', 'v']
# 3
# C:/Users/AlQla/3-class\sol3h.txt
# ['sol', '3', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol3v.txt
# C:/Users/AlQla/3-class\sol3v.txt
# ['sol', '3', 'v']
# 3
# C:/Users/AlQla/3-class\sol4h.txt
# ['sol', '4', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol4v.txt
# C:/Users/AlQla/3-class\sol4v.txt
# ['sol', '4', 'v']
# 3
# C:/Users/AlQla/3-class\sol5h.txt
# ['sol', '5', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol5v.txt
# C:/Users/AlQla/3-class\sol5v.txt
# ['sol', '5', 'v']
# 3
# C:/Users/AlQla/3-class\sol6h.txt
# ['sol', '6', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol6v.txt
# C:/Users/AlQla/3-class\sol6v.txt
# ['sol', '6', 'v']
# 3
# C:/Users/AlQla/3-class\sol7h.txt
# ['sol', '7', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol7v.txt
# C:/Users/AlQla/3-class\sol7v.txt
# ['sol', '7', 'v']
# 3
# C:/Users/AlQla/3-class\sol8h.txt
# ['sol', '8', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol8v.txt
# C:/Users/AlQla/3-class\sol8v.txt
# ['sol', '8', 'v']
# 3
# C:/Users/AlQla/3-class\sol9h.txt
# ['sol', '9', 'h']
# 3
# h
# C:/Users/AlQla/3-class\sol9v.txt
# C:/Users/AlQla/3-class\sol9v.txt
# ['sol', '9', 'v']
# 3
# C:/Users/AlQla/3-class\yukari10h.txt
# ['yukari', '10', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari10v.txt
# C:/Users/AlQla/3-class\yukari10v.txt
# ['yukari', '10', 'v']
# 3
# C:/Users/AlQla/3-class\yukari11h.txt
# ['yukari', '11', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari11v.txt
# C:/Users/AlQla/3-class\yukari11v.txt
# ['yukari', '11', 'v']
# 3
# C:/Users/AlQla/3-class\yukari12h.txt
# ['yukari', '12', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari12v.txt
# C:/Users/AlQla/3-class\yukari12v.txt
# ['yukari', '12', 'v']
# 3
# C:/Users/AlQla/3-class\yukari13h.txt
# ['yukari', '13', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari13v.txt
# C:/Users/AlQla/3-class\yukari13v.txt
# ['yukari', '13', 'v']
# 3
# C:/Users/AlQla/3-class\yukari14h.txt
# ['yukari', '14', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari14v.txt
# C:/Users/AlQla/3-class\yukari14v.txt
# ['yukari', '14', 'v']
# 3
# C:/Users/AlQla/3-class\yukari15h.txt
# ['yukari', '15', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari15v.txt
# C:/Users/AlQla/3-class\yukari15v.txt
# ['yukari', '15', 'v']
# 3
# C:/Users/AlQla/3-class\yukari16h.txt
# ['yukari', '16', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari16v.txt
# C:/Users/AlQla/3-class\yukari16v.txt
# ['yukari', '16', 'v']
# 3
# C:/Users/AlQla/3-class\yukari17h.txt
# ['yukari', '17', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari17v.txt
# C:/Users/AlQla/3-class\yukari17v.txt
# ['yukari', '17', 'v']
# 3
# C:/Users/AlQla/3-class\yukari18h.txt
# ['yukari', '18', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari18v.txt
# C:/Users/AlQla/3-class\yukari18v.txt
# ['yukari', '18', 'v']
# 3
# C:/Users/AlQla/3-class\yukari19h.txt
# ['yukari', '19', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari19v.txt
# C:/Users/AlQla/3-class\yukari19v.txt
# ['yukari', '19', 'v']
# 3
# C:/Users/AlQla/3-class\yukari1h.txt
# ['yukari', '1', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari1v.txt
# C:/Users/AlQla/3-class\yukari1v.txt
# ['yukari', '1', 'v']
# 3
# C:/Users/AlQla/3-class\yukari20h.txt
# ['yukari', '20', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari20v.txt
# C:/Users/AlQla/3-class\yukari20v.txt
# ['yukari', '20', 'v']
# 3
# C:/Users/AlQla/3-class\yukari2h.txt
# ['yukari', '2', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari2v.txt
# C:/Users/AlQla/3-class\yukari2v.txt
# ['yukari', '2', 'v']
# 3
# C:/Users/AlQla/3-class\yukari3h.txt
# ['yukari', '3', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari3v.txt
# C:/Users/AlQla/3-class\yukari3v.txt
# ['yukari', '3', 'v']
# 3
# C:/Users/AlQla/3-class\yukari4h.txt
# ['yukari', '4', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari4v.txt
# C:/Users/AlQla/3-class\yukari4v.txt
# ['yukari', '4', 'v']
# 3
# C:/Users/AlQla/3-class\yukari5h.txt
# ['yukari', '5', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari5v.txt
# C:/Users/AlQla/3-class\yukari5v.txt
# ['yukari', '5', 'v']
# 3
# C:/Users/AlQla/3-class\yukari6h.txt
# ['yukari', '6', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari6v.txt
# C:/Users/AlQla/3-class\yukari6v.txt
# ['yukari', '6', 'v']
# 3
# C:/Users/AlQla/3-class\yukari7h.txt
# ['yukari', '7', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari7v.txt
# C:/Users/AlQla/3-class\yukari7v.txt
# ['yukari', '7', 'v']
# 3
# C:/Users/AlQla/3-class\yukari8h.txt
# ['yukari', '8', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari8v.txt
# C:/Users/AlQla/3-class\yukari8v.txt
# ['yukari', '8', 'v']
# 3
# C:/Users/AlQla/3-class\yukari9h.txt
# ['yukari', '9', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukari9v.txt
# C:/Users/AlQla/3-class\yukari9v.txt
# ['yukari', '9', 'v']
# 3
# C:/Users/AlQla/3-class\yukarih.txt
# ['yukarih']
# C:/Users/AlQla/3-class\yukarı10h.txt
# ['yukarı', '10', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı10v.txt
# C:/Users/AlQla/3-class\yukarı11h.txt
# ['yukarı', '11', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı11v.txt
# C:/Users/AlQla/3-class\yukarı12h.txt
# ['yukarı', '12', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı12v.txt
# C:/Users/AlQla/3-class\yukarı13h.txt
# ['yukarı', '13', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı13v.txt
# C:/Users/AlQla/3-class\yukarı14h.txt
# ['yukarı', '14', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı14v.txt
# C:/Users/AlQla/3-class\yukarı15h.txt
# ['yukarı', '15', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı15v.txt
# C:/Users/AlQla/3-class\yukarı16h.txt
# ['yukarı', '16', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı16v.txt
# C:/Users/AlQla/3-class\yukarı17h.txt
# ['yukarı', '17', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı17v.txt
# C:/Users/AlQla/3-class\yukarı18h.txt
# ['yukarı', '18', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı18v.txt
# C:/Users/AlQla/3-class\yukarı19h.txt
# ['yukarı', '19', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı19v.txt
# C:/Users/AlQla/3-class\yukarı1h.txt
# ['yukarı', '1', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı1v.txt
# C:/Users/AlQla/3-class\yukarı20h.txt
# ['yukarı', '20', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı20v.txt
# C:/Users/AlQla/3-class\yukarı2h.txt
# ['yukarı', '2', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı2v.txt
# C:/Users/AlQla/3-class\yukarı3h.txt
# ['yukarı', '3', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı3v.txt
# C:/Users/AlQla/3-class\yukarı4h.txt
# ['yukarı', '4', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı4v.txt
# C:/Users/AlQla/3-class\yukarı5h.txt
# ['yukarı', '5', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı5v.txt
# C:/Users/AlQla/3-class\yukarı6h.txt
# ['yukarı', '6', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı6v.txt
# C:/Users/AlQla/3-class\yukarı7h.txt
# ['yukarı', '7', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı7v.txt
# C:/Users/AlQla/3-class\yukarı8h.txt
# ['yukarı', '8', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı8v.txt
# C:/Users/AlQla/3-class\yukarı9h.txt
# ['yukarı', '9', 'h']
# 3
# h
# C:/Users/AlQla/3-class\yukarı9v.txt
# C:/Users/AlQla/3-class\yukarıh.txt
# ['yukarıh']
# C:/Users/AlQla/3-class\örnek1.txt
# ['örnek', '1', '']
# 3
# C:/Users/AlQla/3-class\örnek10h.txt
# ['örnek', '10', 'h']
# 3
# C:/Users/AlQla/3-class\örnek11h.txt
# ['örnek', '11', 'h']
# 3
# C:/Users/AlQla/3-class\örnek12h.txt
# ['örnek', '12', 'h']
# 3
# C:/Users/AlQla/3-class\örnek13h.txt
# ['örnek', '13', 'h']
# 3
# C:/Users/AlQla/3-class\örnek14h.txt
# ['örnek', '14', 'h']
# 3
# C:/Users/AlQla/3-class\örnek15h.txt
# ['örnek', '15', 'h']
# 3
# C:/Users/AlQla/3-class\örnek16h.txt
# ['örnek', '16', 'h']
# 3
# C:/Users/AlQla/3-class\örnek17h.txt
# ['örnek', '17', 'h']
# 3
# C:/Users/AlQla/3-class\örnek18h.txt
# ['örnek', '18', 'h']
# 3
# C:/Users/AlQla/3-class\örnek19h.txt
# ['örnek', '19', 'h']
# 3
# C:/Users/AlQla/3-class\örnek1h.txt
# ['örnek', '1', 'h']
# 3
# C:/Users/AlQla/3-class\örnek2.txt
# ['örnek', '2', '']
# 3
# C:/Users/AlQla/3-class\örnek20h.txt
# ['örnek', '20', 'h']
# 3
# C:/Users/AlQla/3-class\örnek21h.txt
# ['örnek', '21', 'h']
# 3
# C:/Users/AlQla/3-class\örnek22h.txt
# ['örnek', '22', 'h']
# 3
# C:/Users/AlQla/3-class\örnek23h.txt
# ['örnek', '23', 'h']
# 3
# C:/Users/AlQla/3-class\örnek24h.txt
# ['örnek', '24', 'h']
# 3
# C:/Users/AlQla/3-class\örnek25h.txt
# ['örnek', '25', 'h']
# 3
# C:/Users/AlQla/3-class\örnek26h.txt
# ['örnek', '26', 'h']
# 3
# C:/Users/AlQla/3-class\örnek27h.txt
# ['örnek', '27', 'h']
# 3
# C:/Users/AlQla/3-class\örnek28h.txt
# ['örnek', '28', 'h']
# 3
# C:/Users/AlQla/3-class\örnek29h.txt
# ['örnek', '29', 'h']
# 3
# C:/Users/AlQla/3-class\örnek2h.txt
# ['örnek', '2', 'h']
# 3
# C:/Users/AlQla/3-class\örnek3.txt
# ['örnek', '3', '']
# 3
# C:/Users/AlQla/3-class\örnek30h.txt
# ['örnek', '30', 'h']
# 3
# C:/Users/AlQla/3-class\örnek31h.txt
# ['örnek', '31', 'h']
# 3
# C:/Users/AlQla/3-class\örnek32h.txt
# ['örnek', '32', 'h']
# 3
# C:/Users/AlQla/3-class\örnek33h.txt
# ['örnek', '33', 'h']
# 3
# C:/Users/AlQla/3-class\örnek34h.txt
# ['örnek', '34', 'h']
# 3
# C:/Users/AlQla/3-class\örnek35h.txt
# ['örnek', '35', 'h']
# 3
# C:/Users/AlQla/3-class\örnek36h.txt
# ['örnek', '36', 'h']
# 3
# C:/Users/AlQla/3-class\örnek37h.txt
# ['örnek', '37', 'h']
# 3
# C:/Users/AlQla/3-class\örnek38h.txt
# ['örnek', '38', 'h']
# 3
# C:/Users/AlQla/3-class\örnek39h.txt
# ['örnek', '39', 'h']
# 3
# C:/Users/AlQla/3-class\örnek3h.txt
# ['örnek', '3', 'h']
# 3
# C:/Users/AlQla/3-class\örnek4.txt
# ['örnek', '4', '']
# 3
# C:/Users/AlQla/3-class\örnek40h.txt
# ['örnek', '40', 'h']
# 3
# C:/Users/AlQla/3-class\örnek4h.txt
# ['örnek', '4', 'h']
# 3
# C:/Users/AlQla/3-class\örnek5.txt
# ['örnek', '5', '']
# 3
# C:/Users/AlQla/3-class\örnek5h.txt
# ['örnek', '5', 'h']
# 3
# C:/Users/AlQla/3-class\örnek6.txt
# ['örnek', '6', '']
# 3
# C:/Users/AlQla/3-class\örnek6h.txt
# ['örnek', '6', 'h']
# 3
# C:/Users/AlQla/3-class\örnek7.txt
# ['örnek', '7', '']
# 3
# C:/Users/AlQla/3-class\örnek7h.txt
# ['örnek', '7', 'h']
# 3
# C:/Users/AlQla/3-class\örnek8.txt
# ['örnek', '8', '']
# 3
# C:/Users/AlQla/3-class\örnek8h.txt
# ['örnek', '8', 'h']
# 3
# C:/Users/AlQla/3-class\örnek9.txt
# ['örnek', '9', '']
# 3
# C:/Users/AlQla/3-class\örnek9h.txt
# ['örnek', '9', 'h']
# 3
# [[ 2.07507204e-01  9.71998168e+01 -2.76496047e+00 ...  2.65906906e+01
#    8.87705718e+02 -4.39303840e+03]
#  [ 2.74348754e-01  7.84450268e+01 -2.89467438e+00 ...  2.15272537e+01
#    7.10564487e+02 -3.60740715e+03]
#  [ 1.93449725e-01  7.19526029e+01 -3.02720556e+00 ...  6.17766930e+00
#    2.17222369e+02 -8.56389523e+02]
#  ...
#  [ 2.39296501e-01  2.43626861e+02  9.60799425e-02 ...  1.01436460e+01
#    3.35723347e+02 -1.23581476e+03]
#  [-1.08356942e-01  1.85207815e+02  1.55962794e+00 ...  9.92107912e+00
#    3.29230915e+02 -1.45881952e+03]
#  [-7.20200439e-01  9.12241342e+01  2.84897414e+00 ...  5.01893765e+00
#    1.92130563e+02 -7.28300499e+02]]

# %%
X_train, X_test, y_train, y_test = train_test_split(raw_features, y, test_size=0.20, random_state=40,stratify = y)
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Initialize the SVC classifier with your desired parameters
svm = SVC(kernel = 'rbf',C = 16)

# Fit the classifier to the training data
svm.fit(X_train, y_train)

# Predict using the classifier
y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

# Calculate the accuracy score
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Train Accuracy:{:.2%}".format(train_accuracy))
print("Test Accuracy:{:.2%}".format(test_accuracy))
error = abs(round(train_accuracy - test_accuracy, 2))
print("Error:", error)

# Confusion matrix
conf_mat = confusion_matrix(y_test, y_test_pred)
print(conf_mat)
plot_confusion_matrix(conf_mat, class_names=["Up 1","Down 2","Right 3","Left 4", "Blink 5"], figsize=(12,5))
# Out:
# Train Accuracy:100.00%
# Test Accuracy:90.00%
# Error: 0.1
# [[3 0 0 1 0]
#  [0 4 0 0 0]
#  [0 0 3 0 1]
#  [0 0 0 4 0]
#  [0 0 0 0 4]]
# (<Figure size 1200x500 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %%
X_train, X_test, y_train, y_test = train_test_split(wavelet_features, y, test_size=0.20, random_state=40,stratify = y)
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Initialize the SVC classifier with your desired parameters
svm = SVC(kernel = 'rbf',C = 16)

# Fit the classifier to the training data
svm.fit(X_train, y_train)

# Predict using the classifier
y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

# Calculate the accuracy score
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Train Accuracy:{:.2%}".format(train_accuracy))
print("Test Accuracy:{:.2%}".format(test_accuracy))
error = abs(round(train_accuracy - test_accuracy, 2))
print("Error:", error)

# Confusion matrix
conf_mat = confusion_matrix(y_test, y_test_pred)
print(conf_mat)
plot_confusion_matrix(conf_mat, class_names=["Up 1","Down 2","Right 3","Left 4", "Blink 5"], figsize=(12,5))
# Out:
# Train Accuracy:88.75%
# Test Accuracy:50.00%
# Error: 0.39
# (<Figure size 1200x500 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %%
X_train, X_test, y_train, y_test = train_test_split(res_rsample, y, test_size=0.20, random_state=40,stratify = y)
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Initialize the SVC classifier with your desired parameters
svm = SVC(kernel = 'rbf',C = 16)

# Fit the classifier to the training data
svm.fit(X_train, y_train)

# Predict using the classifier
y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

# Calculate the accuracy score
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Train Accuracy:{:.2%}".format(train_accuracy))
print("Test Accuracy:{:.2%}".format(test_accuracy))
error = abs(round(train_accuracy - test_accuracy, 2))
print("Error:", error)

# Confusion matrix
conf_mat = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(conf_mat, class_names=["Up 1","Down 2","Right 3","Left 4", "Blink 5"], figsize=(12,5))
# Out:
# Train Accuracy:100.00%
# Test Accuracy:100.00%
# Error: 0.0
# (<Figure size 1200x500 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %%
X_train, X_test, y_train, y_test = train_test_split(combined_features, y, test_size=0.20, random_state=40,stratify = y)
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Initialize the SVC classifier with your desired parameters
svm = SVC(kernel = 'rbf',C = 16)

# Fit the classifier to the training data
svm.fit(X_train, y_train)

# Predict using the classifier
y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

# Calculate the accuracy score
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Train Accuracy:{:.2%}".format(train_accuracy))
print("Test Accuracy:{:.2%}".format(test_accuracy))
error = abs(round(train_accuracy - test_accuracy, 2))
print("Error:", error)

# Confusion matrix
conf_mat = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(conf_mat, class_names=["Up 1","Down 2","Right 3","Left 4", "Blink 5"], figsize=(12,5))
# Out:
# Train Accuracy:100.00%
# Test Accuracy:95.00%
# Error: 0.05
# (<Figure size 1200x500 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %%
X_train, X_test, y_train, y_test = train_test_split(combined_features, y, test_size=0.20, random_state=40,stratify = y)
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
rf_classifier = RandomForestClassifier(n_estimators=200, min_samples_split=5, min_samples_leaf=2)
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
rf_classifier.fit(X_train, y_train)

# Predict using the classifier
y_train_pred = rf_classifier.predict(X_train)
y_test_pred = rf_classifier.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Train Accuracy: {:.2%}".format(train_accuracy))
print("Test Accuracy: {:.2%}".format(test_accuracy))
error = abs(round(train_accuracy - test_accuracy, 2))
print("Error:", error)

# Confusion matrix
conf_mat = confusion_matrix(y_test, y_test_pred)
#plot_confusion_matrix(conf_mat, class_names=["Up 1","Down 2","Right 3","Left 4", "Blink 5"], figsize=(12,5))
# Out:
# Train Accuracy: 98.75%
# Test Accuracy: 85.00%
# Error: 0.14

# %%
xgb_classifier = XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

xgb_classifier.fit(X_train, y_train)

y_train_pred = xgb_classifier.predict(X_train)
y_test_pred = xgb_classifier.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Train Accuracy: {:.2%}".format(train_accuracy))
print("Test Accuracy: {:.2%}".format(test_accuracy))
error = abs(round(train_accuracy - test_accuracy, 2))
print("Error:", error)

# Confusion matrix
conf_mat = confusion_matrix(y_test, y_test_pred)
#plot_confusion_matrix(conf_mat, class_names=["Up 1","Down 2","Right 3","Left 4", "Blink 5"], figsize=(12,5))
# Out:
# Train Accuracy: 100.00%
# Test Accuracy: 75.00%
# Error: 0.25

# %%
import pickle
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix

# Initialize the SVC classifier with your desired parameters
svm = SVC(kernel='rbf', C=16)

# Fit the classifier to the training data
svm.fit(X_train, y_train)

# Predict using the classifier
y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

# Save predictions to a file
with open('predictions.pkl', 'wb') as file:
    pickle.dump({'train': y_train_pred, 'test': y_test_pred}, file)

# Calculate the accuracy score
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Train Accuracy:{:.2%}".format(train_accuracy))
print("Test Accuracy:{:.2%}".format(test_accuracy))
error = abs(round(train_accuracy - test_accuracy, 2))
print("Error:", error)

# Confusion matrix
conf_mat = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(conf_mat, class_names=["Up 1", "Down 2", "Right 3", "Left 4", "Blink 5"], figsize=(12, 5))
# Out:
# Train Accuracy:100.00%
# Test Accuracy:95.00%
# Error: 0.05
# (<Figure size 1200x500 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)
